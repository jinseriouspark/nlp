# %% [markdown]
# 출처 : https://tutorials.pytorch.kr/beginner/text_sentiment_ngrams_tutorial.html

# %%
import torch
import torchtext
from torchtext.datasets import text_classification # 데이터는 이곳에 내장됨
NGRAMS = 2
import os
if not os.path.isdir('./.data'):
    os.mkdir('./.data')
train_dataset, test_dataset = text_classification.DATASETS['AG_NEWS'](
    root='./.data', ngrams=NGRAMS, vocab=None)
BATCH_SIZE = 16
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# ag_news_csv.tar.gz: 11.8MB [00:02, 5.28MB/s]
# 120000lines [00:15, 7621.54lines/s]
# 120000lines [00:38, 3133.77lines/s]
# 7600lines [00:02, 3725.88lines/s]

# %% [markdown]
# ## 모델 정의 하기
#
# - nn.EmbeddingBag 기능으로 임베딩 된 것들을 bag으로 둔다
# - 텍스트 별 길이가 다를 수 있으나, offset 를 통해서 저장되어있음

# %%
import torch.nn as nn
import torch.nn.functional as F
class TextSentiment(nn.Module):
    def __init__(self, vocab_size, embed_dim, num_class):
        super().__init__()
        self.embedding = nn.EmbeddingBag(vocab_size, embed_dim, sparse = True)
        self.fc = nn.Linear(embed_dim, num_class)
        self.init_weights()
        
    def init_weights(self):
        initrange = 0.5
        self.embedding.weight.data.uniform_(-initrange, initrange)
        self.fc.weight.data.uniform_(-initrange, initrange)
        self.fc.bias.data.zero_()
    
    def forward(self, text, offsets):
        embedded = self.embedding(text, offsets)
        return self.fc(embedded)

# %% [markdown]
# ## 인스턴스 생성하기

# %%
VOCAB_SIZE = len(train_dataset.get_vocab())
# train_dataset 은 텐서로 구성되어있어서 .get_vocab() 기능으로 단어 길이 확인할 수있음

EMBED_DIM = 32ㅍ
NUM_CLASS = len(train_dataset.get_labels())
model = TextSentiment(VOCAB_SIZE, EMBED_DIM, NUM_CLASS).to(device)

# %% [markdown]
# ## 배치 생성을 위한 함수들
# - torch.utils.data.DataLoder 의 collate_fn 인자로 넘겨줌

# %%
dir(train_dataset)
# Out:
# ['__add__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_data',
#  '_labels',
#  '_vocab',
#  'get_labels',
#  'get_vocab']

# %%
train_dataset._data 
# train_dataset 은 카테고리 넘버 , text 의 인덱스로 구성된 텐서로 저장되어있다
# Out:
# [(2,
#   tensor([    572,     564,       2,    2326,   49106,     150,      88,       3,
#              1143,      14,      32,      15,      32,      16,  443749,       4,
#               572,     499,      17,      10,  741769,       7,  468770,       4,
#                52,    7019,    1050,     442,       2,   14341,     673,  141447,
#            326092,   55044,    7887,     411,    9870,  628642,      43,      44,
#               144,     145,  299709,  443750,   51274,     703,   14312,      23,
#           1111134,  741770,  411508,  468771,    3779,   86384,  135944,  371666,
#              4052])),
#  (2,
#   tensor([  55003,    1474,    1150,    1832,    7559,      14,      32,      15,
#                32,      16,    1262,    1072,     436,   55003,     131,       4,
#            142576,      33,       6,    8062,      12,     756,  475640,       9,
#            991346,    3186,       8,       3,     698,     329,       4,      33,
#              6764, 1040465,   13979,      11,     278,     483,       7,       3,
#               172,       2,  659973,  193730, 1237754,  684719,  556644,      43,
#                44,     144,     145,   77775,   56578,   32382,  782124,   79225,
#              2908,  140697,  540900,    2031,   31960,   45339,   21562,  936430,
#           1282186,  578442,  991347,   69671,      26,    9260,  717285,    5378,
#               597,   27622, 1070413, 1040466,   38669,   27790,  175394,     711,
#                29,    1404,    1818])),
#  (2,
#   tensor([    78,      9,    469,   8385,    206,     17,    996,     14,     32,
#               15,     32,     16,   3654,    600,    124,   3080, 140201,      3,
#                 6,    2922,       4,     357,     158,    4422,       2,  328521,
#            230536,   21601,  104450,  382222, 1268625,      62,      63,      71,
#                70,    6175,  363633,  302896,  318392,  277960,   51244,    9824,
#               159,    6684,  145876,  393838,    9109,    8395,  249227,  422659,
#            359733,  472666,    5840,   79664,    2080,    9087,     316,   94974,
#            328155,  433903,  103911,  108921,    5291,   49147,     165,   20941,
#            152945,   29847,   10504,   63735,   42376])),
#  (3,
#   tensor([  18561,  125124,      52,   14442,       8,    4438,      28,    7251,
#              8877,    4681,    4438,      14,      36,      15,      67,       3,
#            290901,    2579, 1192147,       8,       3,   79576,   40571,    2453,
#              3339,      20,      78,   37823,       4,  280455,   12088,       9,
#             10346,       7,   87190,       9,   36280,       2,     226,  272380,
#                 3,     182,      17,      10,    1628,   25582,    8124,       4,
#                59,   75804,       3,   10812,      17,      10,   67644,       5,
#            772076,    4615,       9,   41728,      80,       6,  964118,      91,
#                25,   28594,       4,   79316,   13585,   24983,       2,       2,
#                 2,  663712,  669957,  225691,  184527,   74251,  211985,   44244,
#            553773,  818692,    5035,   65865,      62,      63,     584,     918,
#           1214505, 1272914,  587313, 1192148,      26,  458718,  701582,  350212,
#           1104680,  113206,   20009, 1002136,  267164,  497926, 1167723,   88653,
#            224246,   99124,  993097,  670425,  144224,  990663,   28924,  619250,
#            272381,    2389,   30111,      23,   41436, 1162589,  100566,   81221,
#              1379,  836584,  430492,   61130,  433026,      23, 1110998,  109987,
#           1229663,  772077,  270379,  317945, 1236499,    2546,  544524,  964119,
#             10105,   42829,  405215,  297249,  669949,  637802, 1001773,      37,
#                37])),
#  (3,
#   tensor([  1871,     61,   9774,      7,    101,    230,     28,   3770, 811725,
#              769,    814,     14,     36,     15,     67, 233818,     85,      2,
#                4,      3,  10555,   1888,    214,      4,     24,      6, 116083,
#                8,   1795,     16,      6,     72,     19,  20590,  32230,    101,
#              115,      2,     14,   4406,     15,    230,      9,  33820,     11,
#               30,  26105,      5,  48191,      4,   2306,      9,   2802,      3,
#             3372,     30,  82937,      5,    683,      2,      2,      2, 240926,
#           479966,  14342,   6250,  74877,  65422, 178979, 809366, 811726,    822,
#             4291,     62,     63,    584, 502056, 338958,     89,    253,     42,
#           459246, 383932, 404043,   4307,    734,    748, 122122, 271943,  34780,
#           848997,    296,   4116,   4993, 457614, 353461, 355168,    981,    126,
#              384,  13942,  12119,  20455,   8913, 317615,  41380,  14744, 386125,
#            80044,  84344, 466554, 140997, 426003, 224092, 149268,  61112, 404059,
#           386225, 431998,  19188,   5494,     37,     37])),
#  ...]

# %%
train_dataset.get_labels() # 카테고리 라벨 4개
# Out:
# {0, 1, 2, 3}

# %%
train_dataset._vocab
# Out:
# <torchtext.vocab.Vocab object at 0x7f935eb122b0>

# %%
dir(train_dataset._vocab)
# Out:
# ['UNK',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_default_unk_index',
#  'extend',
#  'freqs',
#  'itos',
#  'load_vectors',
#  'set_vectors',
#  'stoi',
#  'unk_index',
#  'vectors']

# %%
train_dataset._vocab.freqs # 발생한 단어들의 프리퀀시는 여기 저장되어있음
# Out:
# Counter({'laid his': 1,
#          'music illegally': 6,
#          'in bitdefender': 1,
#          'trialing the': 1,
#          'snow\\repeated on': 1,
#          '41-20 ,': 1,
#          'catastrophe .': 5,
#          'school dormitory': 8,
#          'still crunching': 1,
#          'bankrupt\\united': 1,
#          'irs pledges': 1,
#          'witty': 4,
#          'mcdonalds says': 1,
#          'rename cnet': 1,
#          'acquisition .': 15,
#          'whole story': 2,
#          'the mick': 1,
#          'attendees say': 1,
#          'postal rider': 1,
#          'practice 3': 2,
#          'rename companies': 1,
#          'company 3com': 1,
#          'software programmes': 1,
#          'recalls cell': 1,
#          '55-yard field': 4,
#          'addresses rally': 1,
#          're-draw the': 1,
#          'the\\brink of': 2,
#          'canada to': 55,
#          'estimates that': 14,
#          'posts bent': 1,
#          "novak '": 1,
#          'official sana': 3,
#          'eyes london': 1,
#          'rebels turned': 1,
#          's molecules': 1,
#          'assurance to': 1,
#          'spin mccardell': 1,
#          'shugofa beheshti': 1,
#          'in\\ukraine': 1,
#          ', guarded': 1,
#          'above \\$us51': 1,
#          'higher stock': 1,
#          'to pore': 1,
#          'search like': 1,
#          'filtering firm': 3,
#          'round-trip journey': 1,
#          'second attack': 4,
#          'has shuffled': 1,
#          'and greeting': 1,
#          'fish department': 1,
#          'shanghai second-seeded': 1,
#          'expand overseas': 1,
#          'infertile by': 2,
#          'bankruptcies are': 1,
#          'bolt could': 1,
#          '2005 tournament': 2,
#          'tourism spawned': 1,
#          'today became': 1,
#          'object beyond': 3,
#          'while creating': 3,
#          'nortel names': 1,
#          'staley makes': 1,
#          'dollar investment': 1,
#          'truck and': 9,
#          '260km': 1,
#          't seek': 8,
#          'trade name': 1,
#          'nuclear bomb': 27,
#          "' cell": 7,
#          'seven boundaries': 1,
#          'sharper-than-expected 0': 1,
#          'iv -': 1,
#          'senate report': 3,
#          'lukashenko of': 2,
#          ', wilco': 1,
#          'box seats': 2,
#          'before international': 1,
#          'airlines feel': 1,
#          'deal i': 1,
#          'messy business': 1,
#          'band for': 2,
#          'beatifies emperor': 3,
#          'eriksson as': 1,
#          'single answer': 1,
#          'leader khaled': 4,
#          'expensive doorstops': 2,
#          'fit-again wayne': 1,
#          'browser the': 6,
#          'ninth-ranked buckeyes': 3,
#          'the\\burgeoning': 1,
#          'either side': 8,
#          'give iesi': 1,
#          'vienna .': 14,
#          'tony perkins': 2,
#          'vote left': 1,
#          'symantec e-commerce': 1,
#          'like cancer': 2,
#          'occurred within': 1,
#          'attract programmer': 1,
#          'traditional winter': 1,
#          'waitresses ,': 1,
#          'larraine': 1,
#          'with map': 1,
#          'account cards': 1,
#          'backing': 219,
#          'exchange prisoners': 3,
#          'richard a': 2,
#          'dual-format': 4,
#          'says as': 3,
#          'rookie to': 2,
#          'wrong number': 1,
#          'nuclear dossier': 3,
#          'significant data': 1,
#          'traders attempted': 1,
#          'overturn intel': 1,
#          'euro music': 2,
#          'latest fuel': 1,
#          'fullback talib': 1,
#          'damaris ochoa': 1,
#          's menlo': 4,
#          '\\$4m breeders': 1,
#          'length slump': 1,
#          'shopping over': 1,
#          'students using': 1,
#          'unexpected twist': 2,
#          'suzuki and': 2,
#          'thai local': 1,
#          'golfer goosen': 1,
#          'which labor': 1,
#          'centrica says': 1,
#          'stokes fire': 1,
#          'appeared': 385,
#          'draining away': 1,
#          'swiss dominated': 1,
#          'into networks': 1,
#          'quot added': 1,
#          "subsidiaries '": 1,
#          'opteron san': 2,
#          'felix cardenas': 3,
#          'concessions gives': 1,
#          'japan optimism': 1,
#          '2002 allard': 1,
#          'sas are': 1,
#          'panathinaikos would': 1,
#          'suit roundup': 2,
#          'll start': 3,
#          'all regions': 3,
#          'revealed friday': 2,
#          '12-round majority': 1,
#          'murthy': 1,
#          'watch soldier': 11,
#          'donald has': 2,
#          'oil security': 3,
#          'the landers': 1,
#          'other day': 20,
#          'rainmeister michael': 1,
#          'figures released': 18,
#          'baseball-crazed country': 1,
#          'go-ahead the': 2,
#          'predictions .': 1,
#          'complicated .': 2,
#          'unbearable': 5,
#          'strides it': 1,
#          'lahore australia': 1,
#          'changing climate': 4,
#          'accelerate new': 4,
#          'bioengineering': 1,
#          'interview backman': 2,
#          'power minsk': 1,
#          'govt lithuanian': 1,
#          "pc '": 14,
#          'agonized through': 1,
#          'beenmade an': 1,
#          'famous web': 1,
#          '24-10 for': 1,
#          'scenes as': 1,
#          'lawmakers eye': 1,
#          'vera quot': 1,
#          'alay soler': 2,
#          '13- mile': 1,
#          'heritage yesterday': 1,
#          'surgery a': 4,
#          'pic ring-tailed': 1,
#          '1-ecclestone sets': 1,
#          'pass laws': 4,
#          'rods ,': 1,
#          'matches both': 1,
#          'created mainstream': 1,
#          '. sanfilippo': 2,
#          'examining the': 12,
#          'worded challenge': 2,
#          'wisconsin ncaaf': 1,
#          'biggest holding': 1,
#          'at plenary': 1,
#          '2q dillard': 1,
#          'welcomed news': 3,
#          'pumped some': 2,
#          'supply u': 1,
#          'children chatter': 1,
#          'shuttle loss': 1,
#          'hours three': 1,
#          ') scandal': 2,
#          'delivering applications': 1,
#          'connections through': 1,
#          'result philadelphia': 1,
#          'the hopkins': 1,
#          'homes to': 5,
#          'scripps senior': 1,
#          'street rings': 1,
#          'raised this': 1,
#          'belarus hot': 1,
#          'khatami': 43,
#          'acquiring suse': 1,
#          'reserve reuters': 1,
#          'crew made': 3,
#          'past longhorns': 1,
#          'asias newest': 1,
#          'force shell': 1,
#          '60th': 10,
#          '17-yard touchdown': 2,
#          '( monotheism': 1,
#          'survival posh': 1,
#          'state leonid': 1,
#          'detained but': 1,
#          'with revenue': 4,
#          'kurdish &lt': 2,
#          'shores-based': 4,
#          'new move': 1,
#          'its 48th': 2,
#          'critical #39': 12,
#          'felt across': 2,
#          'authorities tuesday': 2,
#          'willingham nov': 1,
#          '\\$100-plus sneaker': 1,
#          'rex ,': 4,
#          'the solvency': 2,
#          'two-match ban': 5,
#          'search bringing': 1,
#          'fudged .': 1,
#          'seized hundreds': 1,
#          "nuke '": 3,
#          'cycle rangers': 1,
#          'meeting bangkok': 1,
#          'marijuana in': 2,
#          'bookmakers forecast': 1,
#          '2 st': 1,
#          'facing intermittent': 1,
#          'expectation that': 2,
#          'showed opposition': 1,
#          '24 pass': 2,
#          'spaniard sete': 4,
#          '500m and': 1,
#          'continued reign': 1,
#          'rings summary': 1,
#          'phone cover': 6,
#          'behaves': 1,
#          '( delbt': 1,
#          'condition for': 9,
#          'itil best': 1,
#          'thai telecoms': 1,
#          'late indian': 1,
#          'kerry follow': 2,
#          'defense giant': 6,
#          'reverse course': 2,
#          'unveils four': 1,
#          'asia came': 1,
#          'ming dwarfed': 1,
#          "' brutal": 1,
#          'pilots went': 1,
#          'carr on': 1,
#          'stars raise': 1,
#          ') file': 10,
#          '#39 spaceshipone': 1,
#          'cost controls': 12,
#          'insurgent mahdi': 1,
#          'farina': 27,
#          'initial ranking': 1,
#          'pro training': 1,
#          'over speech': 1,
#          'his delegation': 1,
#          'theater usually': 1,
#          'astonishing way': 1,
#          'open 54': 2,
#          '13 runs': 2,
#          'quickly are': 1,
#          '. pro': 2,
#          ', laying': 6,
#          'admits to': 21,
#          'in tomorrows': 5,
#          'his handling': 8,
#          'very angry': 1,
#          'relayed by': 1,
#          'street reform': 1,
#          'avoid adding': 4,
#          'feed doubts': 1,
#          'says canadians': 2,
#          'ruling reversed': 2,
#          'were atmosp-here': 1,
#          'eluded and': 1,
#          'pre-tax profits': 10,
#          'machine business': 1,
#          'crowd against': 2,
#          'david hasselhoff': 1,
#          'vioxx defense': 1,
#          'fires winner': 1,
#          'walter johnson': 1,
#          'several cities': 4,
#          'officer suggests': 1,
#          'french plan': 2,
#          '. craigslist': 4,
#          'hotmail london': 1,
#          'mcgahee made': 1,
#          'finger-pointing ,': 1,
#          'magnitude earthquake': 4,
#          'youths who': 2,
#          'have hurt': 3,
#          'of stalking': 7,
#          'tehran seeking': 3,
#          'slickest hi-tech': 1,
#          'india among': 3,
#          'policies against': 4,
#          'comp .': 1,
#          'florida fans': 2,
#          'the\\senate': 3,
#          'awaiting information': 1,
#          'deke cooper': 1,
#          '#39 african': 1,
#          'sox bash': 1,
#          'states can': 12,
#          'full outlook': 1,
#          'third-place game': 4,
#          'confirms adelstein': 1,
#          'amid subscriber': 1,
#          '2004 postseason': 1,
#          'institute and': 8,
#          'sfa eye': 1,
#          'other crimes': 2,
#          'attack misfires': 1,
#          'now watch': 2,
#          'managers --': 1,
#          'mars watery': 1,
#          'kohl': 12,
#          'hellweg': 1,
#          'etat when': 1,
#          'with noisy': 1,
#          ', source': 3,
#          'preview for': 5,
#          'cingular interactive': 1,
#          'unconverted public': 1,
#          'dng photo': 1,
#          'be laid': 4,
#          'bonn --': 1,
#          'between tens': 1,
#          'eyeing bowl': 1,
#          'human might': 1,
#          '( bronson': 1,
#          'a two-year-old\\boy': 1,
#          'ftc goes': 2,
#          'over revolutionary': 1,
#          'an exhilarating': 1,
#          'tech amp': 1,
#          'us carriers': 6,
#          'national indian': 2,
#          'see geminid': 1,
#          'may cash': 1,
#          'sinai': 97,
#          'houston-- (': 1,
#          'that defuses': 1,
#          'least \\$550': 1,
#          "humankind '": 1,
#          'paypal at': 1,
#          'been finalized': 2,
#          'referrals': 3,
#          'bankers on': 1,
#          'feels fury': 1,
#          'ajax or': 1,
#          'honda help': 1,
#          'capital management': 43,
#          'contacted': 34,
#          'for el': 5,
#          'stacked bodies': 3,
#          'endless battle': 1,
#          'beltran set': 1,
#          'sheffield #39': 2,
#          'historic trends': 1,
#          'tighten border': 1,
#          'after his': 255,
#          '\\\\over at': 1,
#          'strike reports': 1,
#          'why .': 18,
#          'the heals': 1,
#          'named mom': 1,
#          'company\\freddie': 1,
#          'surgeon whose': 1,
#          'are having': 15,
#          'kill journalist': 2,
#          'novocould': 1,
#          'foetal tissues': 1,
#          'dico': 1,
#          'bomb as': 3,
#          'arafat compound': 2,
#          'are technically': 1,
#          'milan courthouse': 1,
#          'closing celebrations': 3,
#          'sony releases': 2,
#          'player priced': 1,
#          'the a\\$3': 1,
#          'pakistanis divided': 1,
#          'republican\\florida': 1,
#          'saidullayeva': 1,
#          'for telemarketing': 1,
#          'airport profit': 1,
#          'only flashpoint': 1,
#          'other impediments': 1,
#          'drought grenada': 1,
#          'rewind dodgers': 1,
#          'four armed': 1,
#          'militant known': 2,
#          'talks took': 2,
#          'again crude': 2,
#          'moment as': 2,
#          'million bribery': 2,
#          'a clothing': 3,
#          'snapshot quot': 1,
#          'you grew': 1,
#          'employment center': 1,
#          'bullish about': 7,
#          'bellamy newcastle': 2,
#          'performer within': 1,
#          'incumbent rival': 1,
#          '/b&gt delaware': 1,
#          'hotline india': 1,
#          'v890': 2,
#          'retain positions': 1,
#          's developing': 4,
#          'sherpur town': 1,
#          'defeat us': 2,
#          'its hard-drive': 1,
#          'producer wednesday': 1,
#          'deem': 2,
#          'that performs': 1,
#          'sixteenth .': 1,
#          'household whether': 1,
#          '#39 paisley': 1,
#          'repealed\\illegal': 1,
#          'passengers would': 1,
#          'had wanted': 3,
#          'landmark settlement': 1,
#          'new socialist': 1,
#          'incident bolton': 1,
#          'feebly as': 1,
#          'sapphire': 1,
#          'back problem': 3,
#          'sundarbans': 1,
#          'eserver': 62,
#          '- \\$440': 1,
#          'liens': 1,
#          'her compatriots': 2,
#          'iraq murder': 2,
#          'teams atop': 1,
#          'cdma2000 1xev-do': 1,
#          'tuesday if': 2,
#          'that day': 14,
#          'mexico lands': 1,
#          'endorse concessions': 1,
#          'limbs': 7,
#          'meshes': 1,
#          'women apparently': 1,
#          '- government': 10,
#          'free cars': 1,
#          '850/900/1800/1900': 2,
#          'jamaica has': 2,
#          'about russian': 3,
#          'provides antifraud': 1,
#          'zealand divisions': 1,
#          '. weather': 12,
#          'arsenals winning': 1,
#          'serve longer': 1,
#          '. presidential': 51,
#          "' bandwidth": 1,
#          'premium services': 3,
#          'not expand': 5,
#          'exam at': 1,
#          'resist polar': 1,
#          'exec castagna': 1,
#          'dollar came': 2,
#          'sang along': 1,
#          'sharp prodding': 2,
#          'iraq first': 1,
#          'mean creek': 1,
#          'cracking software': 1,
#          'study starvation': 1,
#          'from hawaii': 1,
#          'fathom': 2,
#          'cities such': 1,
#          'schoolteacher': 4,
#          'upgrade not': 1,
#          'key clue': 1,
#          'would improve': 1,
#          'maker saw': 7,
#          'energizer holdings': 1,
#          'harness that': 2,
#          'build \\': 1,
#          'still value': 1,
#          'digital home': 23,
#          'lower wages': 1,
#          'update&lt': 2,
#          'displaced': 64,
#          'yet': 895,
#          'windows-based web': 1,
#          'nelsons take': 1,
#          'banik': 2,
#          'schilling went': 1,
#          'compare features': 1,
#          'uk trade': 3,
#          'not amended': 1,
#          'unexpected findings': 3,
#          'carter finds': 1,
#          'jays rallies': 1,
#          'e-mailed statement': 4,
#          'a four-stroke': 9,
#          'on ufj': 2,
#          'lead philadelphia': 1,
#          'treating practice': 1,
#          'and dumb': 1,
#          '? bee': 2,
#          'rebounding global': 1,
#          'alive of': 1,
#          'the customarily': 1,
#          'polls #39': 1,
#          '1994': 49,
#          'netsuite has': 3,
#          'charts and': 5,
#          '- amateur': 3,
#          'sales that': 13,
#          'sony clie': 1,
#          'issues remain': 2,
#          'quot col': 1,
#          'nasa bid': 1,
#          'gained tentatively': 2,
#          'minnows bangladesh': 1,
#          '32-25 win': 2,
#          'raising output': 1,
#          'unionize (': 3,
#          'record-breaking oil': 5,
#          'mike petke': 1,
#          'trainer links': 1,
#          'annonces ce': 1,
#          'voluntarily clean': 1,
#          'miss by': 3,
#          'clueless the': 1,
#          'eyes on': 34,
#          'woes unknown': 1,
#          'pegasus xl': 1,
#          'agm begins': 1,
#          'an agepoll': 1,
#          'rovers jet': 1,
#          'the 9300': 1,
#          'damage again': 1,
#          'downers grove': 1,
#          'wednesday\\launched': 2,
#          'teammate carlos': 2,
#          'mines from': 1,
#          'being substituted': 2,
#          'what rights': 2,
#          'warners': 1,
#          'is accessible': 1,
#          'medical work': 1,
#          'birds brian': 1,
#          'director accused': 2,
#          'run streak': 1,
#          'amid united': 2,
#          'probe missing': 1,
#          'linking france': 1,
#          'yet be': 10,
#          'and unfixed': 1,
#          'surhoff hit': 1,
#          'who lead': 4,
#          '#39 fischer': 1,
#          'upset when': 2,
#          'code but': 1,
#          'odds )': 1,
#          'realnetworks promotion': 1,
#          'rally back': 2,
#          'governor which': 1,
#          'with s': 1,
#          'off virtually': 1,
#          'as huge': 3,
#          'ind': 61,
#          'raptors get': 1,
#          'globe said': 2,
#          'a million-square-foot': 1,
#          'hesitant display': 1,
#          'dui (': 3,
#          'treaty moscow': 2,
#          'mac are': 2,
#          'highs the': 2,
#          'player dissension': 1,
#          'pounded\\the tiny': 1,
#          'liquidate frank': 1,
#          'low-end and': 1,
#          'biggest parties': 3,
#          'and molson': 1,
#          'mean after': 1,
#          'coach whose': 1,
#          'alleged saddam': 1,
#          'quot complaint': 1,
#          'we assume': 1,
#          's facility': 1,
#          'definitely travels': 1,
#          'ad accuses': 1,
#          'third-year coach': 3,
#          'double its': 17,
#          'nancy workman': 1,
#          'remember ron': 1,
#          'technology added': 1,
#          'swinging': 27,
#          'day blast': 1,
#          'hosni': 22,
#          'blockbuster atlantic': 1,
#          'rochester-area': 1,
#          'lawson': 8,
#          'stanton out': 1,
#          'higher revenue': 15,
#          'commander to': 4,
#          'gwr group': 4,
#          'remarkable ,': 2,
#          'ut club': 1,
#          'long-awaited slowdown': 1,
#          'mainframe customers': 1,
#          '68-48 saturday': 1,
#          'seventh-': 4,
#          'quot certainly': 1,
#          'age (': 1,
#          'children need': 2,
#          'beau in': 1,
#          'smith injured': 1,
#          'is supporting': 4,
#          'wins opener': 2,
#          'separate proposals': 1,
#          'quicken windows': 1,
#          'totaling \\$294': 1,
#          'extreme': 109,
#          'held cargill': 2,
#          'reportedly tried': 1,
#          'stalemated peace': 1,
#          'were adequately': 1,
#          'your insurer': 1,
#          'experts awake': 1,
#          'and\\south korea': 1,
#          'problems afflicting': 1,
#          "' russian": 3,
#          'rovers 3-0': 1,
#          '000 bonus': 2,
#          'cousin fighting': 1,
#          'destroyed him': 1,
#          'wrong things': 1,
#          'a budget': 18,
#          'taught the': 4,
#          'adventurer mike': 1,
#          'advises fannie': 2,
#          'takes england-lanka': 1,
#          'patents related': 2,
#          'room floor': 1,
#          'moldova .': 7,
#          'near rafah': 2,
#          'seemingly provided': 1,
#          'hockey whitehorse': 1,
#          'materialises': 1,
#          '#39 were': 1,
#          'confront': 37,
#          'community had': 2,
#          'reached on': 18,
#          'growing anxieties': 1,
#          'that ensured': 2,
#          'who bring': 3,
#          'maxii tops': 3,
#          'familiar #151': 1,
#          'gta/pstwo bundle': 1,
#          'maker wm': 3,
#          'trump #39': 21,
#          'favoring indias': 1,
#          'with britains': 1,
#          'sales bellevue': 1,
#          'and purses': 1,
#          'beverage is': 1,
#          'explorer case': 2,
#          'blesses': 9,
#          'a paradise': 1,
#          'month journey': 1,
#          'electric miniature': 1,
#          'a rag-tag': 2,
#          '- forbes': 2,
#          'feel a': 7,
#          'euros per': 1,
#          'develop video': 3,
#          '000 saturday': 1,
#          'chile': 225,
#          'bidder time': 1,
#          'more divided': 1,
#          'election iraqi': 2,
#          'them\\some of': 1,
#          'with sister': 1,
#          'behalf ,': 2,
#          'in trans': 1,
#          'inception in': 5,
#          'pm )': 16,
#          'top form': 10,
#          'world india': 1,
#          'election behind': 2,
#          'of foxes': 1,
#          'par': 68,
#          'reuters the': 1,
#          'heads it': 1,
#          'britons party': 1,
#          'a comparitively': 1,
#          'the automated': 3,
#          'wrinkle the': 1,
#          'plan waltham': 1,
#          'and \\$2': 7,
#          '129 in': 3,
#          'are hotly': 1,
#          '4 work': 1,
#          'earthquake happened': 1,
#          'button had': 2,
#          'favorable to': 4,
#          '- smashing': 2,
#          'in 1861': 1,
#          'cumbie throwing': 1,
#          'scientists tried': 1,
#          'hills course': 1,
#          'beaches and': 5,
#          'fired head': 5,
#          'game blood': 1,
#          'and 2': 13,
#          'anbar &lt': 1,
#          'offices wednesday': 1,
#          'surveillance satellite': 1,
#          'radicalization of': 1,
#          'france last': 1,
#          'of 79': 1,
#          '291': 2,
#          'device by': 2,
#          'reversing a': 40,
#          '10year deal': 1,
#          'fetch': 15,
#          'stock\\markets': 1,
#          'sad and': 4,
#          'a strugglers': 2,
#          'spam made': 1,
#          'finance professionals': 2,
#          'miss subways': 1,
#          'auriemma has': 1,
#          'of burgos': 1,
#          'brightest lights': 1,
#          'continuing power': 1,
#          'democratic sen': 31,
#          'necessarily mean': 3,
#          'paintings ,': 3,
#          'continue but': 2,
#          'mission accomplished': 6,
#          'mainstay at': 1,
#          'seven-day strike': 1,
#          'after reporting': 16,
#          'respected advisory': 1,
#          'horton earnings': 1,
#          'losing key': 2,
#          'exuberant sergio': 1,
#          'lethal palestinian': 2,
#          'catholic and': 4,
#          'cards power': 1,
#          'move clear': 2,
#          'battling cartoon': 1,
#          'three early': 3,
#          'the rochester': 1,
#          'have bill': 2,
#          'doubt thursday': 3,
#          'damages to': 7,
#          'foma handsets': 4,
#          'stand ready': 2,
#          'of advanced': 23,
#          '48-27 rout': 1,
#          'ferencvaros charged': 1,
#          'shelters monday': 1,
#          'soros ,': 4,
#          'they thought': 4,
#          'and valve': 2,
#          'stranded residents': 1,
#          'weekend inspected': 1,
#          'two-under-par 68': 3,
#          'saturday which': 2,
#          'space shuttle': 156,
#          'to opec': 5,
#          'orbit on': 9,
#          'reforms since': 3,
#          '000-seat ballpark': 1,
#          'damage phase': 1,
#          'zbikowski': 4,
#          'increase sydney': 1,
#          'burning city': 3,
#          'british store': 1,
#          'conference tracks': 1,
#          'liftoff and': 1,
#          'storage vendors': 8,
#          'its listing': 4,
#          'election brussels': 1,
#          '. once': 17,
#          'also authorized': 1,
#          'to m': 1,
#          'disclaimers on': 4,
#          'icann approves': 1,
#          'mobility group': 1,
#          'achieved more': 1,
#          'benefits thai': 1,
#          'polanco': 6,
#          'hill thursday': 1,
#          'geographic information': 1,
#          'announced sept': 1,
#          'evacuate its': 1,
#          'dixons has': 2,
#          'same city': 3,
#          'acquired marktplaats': 1,
#          'and urged': 61,
#          'ones': 144,
#          'refreshing !': 1,
#          'overall lack': 1,
#          'yudhoyono defeated': 1,
#          'non-gamblers .': 1,
#          'rocks voltchkov': 1,
#          'sharapova signs': 1,
#          'of concession': 1,
#          'quickly move': 1,
#          'points before': 1,
#          'interbrew ambev': 1,
#          'hunted on': 1,
#          ', agere': 2,
#          'glee in': 1,
#          'shakes northern': 6,
#          'bucks': 74,
#          'james as': 2,
#          'ibm recalls': 12,
#          'regalia .': 2,
#          'criminalize &lt': 1,
#          'did they': 9,
#          'nerds': 3,
#          'anti-internet': 1,
#          'off-field drama': 2,
#          'bremer talk': 1,
#          'ban utrecht': 1,
#          'laureate joins': 1,
#          'on finalizing': 3,
#          'at job': 1,
#          'really ?': 2,
#          'announces dual-core': 5,
#          '48 f-16': 1,
#          'entertainment some': 1,
#          '( scs': 1,
#          'to um': 1,
#          'with shi': 6,
#          'dithers ,': 1,
#          ') warner': 1,
#          'sudan wars': 1,
#          'pepper-ball': 1,
#          'scoops spanish': 1,
#          'over reported': 2,
#          'defense troops': 1,
#          'cases nearly': 1,
#          'poaching novell': 1,
#          'year continental': 1,
#          'bubble burst': 5,
#          'peoplesoft financial': 1,
#          'lights that': 1,
#          ', 364-foot': 1,
#          'grammy show': 1,
#          'profitability amid': 1,
#          'titan sent': 1,
#          'clarett accusations': 1,
#          'aggregation of': 1,
#          'resume dissident': 1,
#          'f1 board': 1,
#          'blockbuster called': 1,
#          'objects like': 1,
#          'valentin #39': 1,
#          'other cost': 5,
#          'then surviving': 2,
#          'pagnotta': 1,
#          'news sun': 1,
#          ', campaigned': 1,
#          'small brokerage': 1,
#          '84th new': 1,
#          'services initiative': 1,
#          'traveling band': 1,
#          'maryland basketball': 1,
#          'eggs .': 5,
#          'reads im': 1,
#          'oil pricing': 2,
#          'recoletos britain': 1,
#          'renewed fears': 7,
#          'unbelievable as': 1,
#          'at agencourt': 1,
#          '? ticker=ad': 1,
#          'kong pro-democracy': 10,
#          'disappoints (': 5,
#          'a taxpayer-financed': 1,
#          'caminiti an': 1,
#          'expand services': 1,
#          'champion japan': 1,
#          '25/11/04': 2,
#          '40 countries': 4,
#          'dvd\\promotional': 1,
#          'leaves early': 1,
#          "' lake": 1,
#          'increased productivity': 1,
#          'down australia': 1,
#          'transmit': 18,
#          'from airing': 2,
#          'distribute music': 1,
#          'be there': 6,
#          'ds6000 i': 1,
#          'sydney flights': 1,
#          'unlisted telecom': 1,
#          '45 per': 1,
#          'helps publishers': 2,
#          'builder toll': 1,
#          'doohan': 2,
#          'gas spat': 1,
#          'trekked': 3,
#          's four-match': 1,
#          'horror 20': 1,
#          'as pharmacy': 2,
#          'boulevard looks': 1,
#          'costly media': 1,
#          'for 124': 3,
#          "insulting '": 1,
#          'his push': 4,
#          'it achieved': 1,
#          'an aeroplane': 1,
#          'effort lycos': 1,
#          'airlines announced': 3,
#          '8 days': 2,
#          'sees when': 1,
#          'rests injury': 1,
#          'finale was': 1,
#          'unsubscribing from': 1,
#          'before aides': 1,
#          'predatory reptiles': 1,
#          'with new-age': 1,
#          'assured as': 1,
#          'secular dutch': 1,
#          'kellogg co': 18,
#          'become friends': 1,
#          'provide managed': 3,
#          'seemingly vying': 1,
#          'banks control': 1,
#          'breath longer': 1,
#          'russa ,': 3,
#          'eastwards': 1,
#          'arab-language': 1,
#          'rfid services': 11,
#          'mitsui post': 1,
#          'plowed through': 1,
#          'americas highest': 1,
#          'grammys .': 2,
#          'call norton': 1,
#          'in benefits': 2,
#          'aol buddy': 1,
#          'and cleveland': 12,
#          'siege': 226,
#          'shook northern': 8,
#          'severely violates': 1,
#          'hazardous': 26,
#          'opec group': 1,
#          'debt holdings': 2,
#          'stewart arrives': 1,
#          'along wherever': 1,
#          'austrian feminist': 1,
#          'been at': 12,
#          'tagmastore storage': 1,
#          'fraught': 12,
#          'as an\\e-mail': 1,
#          'one loss': 4,
#          'madrid american': 1,
#          'arrived from': 6,
#          'four-week loan': 1,
#          'disruptive labor': 1,
#          'online free': 2,
#          'bill worrell': 1,
#          'interim leader': 43,
#          'gold how': 1,
#          'jjb': 5,
#          'cap an': 5,
#          'plant cleared': 1,
#          'decade trade': 1,
#          'longest shutout-free': 1,
#          'beat microsoft': 1,
#          'boy near': 2,
#          'his pants': 1,
#          'washington\\resisted europe': 1,
#          'claims and': 18,
#          ...})

# %%
vectors
